# %%
import requests
import json

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '8501840863',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 409872877,
#    'name': 'yegor256/debate',
#    'url': 'https://api.github.com/repos/yegor256/debate'},
#   'payload': {'repository_id': 409872877,
#    'push_id': 30796802456,
#    'ref': 'refs/heads/renovate/crate-ci-typos-1.x',
#    'head': '8438676f286fd8c8f69faa94cd07ca0b920d5a94',
#    'before': '42af1136378a54279e64c834a59c3f97f9b26417'},
#   'public': True,
#   'created_at': '2026-02-16T17:59:52Z'},
#  {'id': '8501840718',
#   'type': 'PushEvent',
#   'actor': {'id': 1047040,
#    'login': 'vrdmr',
#    'display_login': 'vrdmr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vrdmr',
# ...
